# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("dataset/Sample_Data_for_Activity.csv")
df.head()
# Out:
#    Normal_Distribution  Uniform_Distribution  Exponential_Distribution  \
# 0            57.450712             30.048955                  2.472682
# 1            47.926035             26.274070                  0.374126
# 2            59.715328             58.185815                  1.143180
# 3            72.845448             62.388544                  4.137906
# 4            46.487699             21.895169                 16.224506
#
#    Poisson_Distribution
# 0                     4
# 1                     5
# 2                     4
# 3                     1
# 4                     3

# %%
sns.displot(df['Normal_Distribution'], kde=True)

# %%
sns.displot(df['Uniform_Distribution'], kde=True)

# %%
sns.jointplot(x='Normal_Distribution', y='Uniform_Distribution', data=df, kind='scatter')

# %%
sns.jointplot(x='Normal_Distribution', y='Uniform_Distribution', data=df, kind='reg')
